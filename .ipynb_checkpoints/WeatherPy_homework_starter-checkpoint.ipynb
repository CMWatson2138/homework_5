# %% [markdown]
# # Assignment - What's the Weather Like?
#
# ## Background
#
# Whether financial, political, or social -- data's true power lies in its ability to answer questions definitively. So let's take what you've learned about Python requests, APIs, and JSON traversals to answer a fundamental question: "What's the weather like as we approach the equator?"
#
# Now, we know what you may be thinking: _"Duh. It gets hotter..."_
#
# But, if pressed, how would you **provide evidence**?
#
# ## WeatherPy
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * OPTIONAL: Include a print log of each city as it's being processed with the city number and city name.
# * OPTIONAL: Save both a CSV of all data retrieved and png images for each scatter plot.
#
# As final considerations:
#
# * You must complete your analysis using a Jupyter notebook.
# * You must use the Matplotlib ,Seaborn or Pandas plotting libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
#
# ## Hints and Considerations
#
# * The city data is generated based on random coordinates; as such, your outputs will not be an exact match to the provided starter notebook.
#
# * You may want to start this assignment by refreshing yourself on the [geographic coordinate system](http://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm).
#
# * Next, spend the requisite time necessary to study the OpenWeatherMap API. Based on your initial study, you should be able to answer  basic questions about the API: Where do you request the API key? Which Weather API in particular will you need? What URL endpoints does it expect? What JSON structure does it respond with? Before you write a line of code, you should be aiming to have a crystal clear understanding of your intended outcome.
#
# * A starter code for Citipy has been provided. However, if you're craving an extra challenge, push yourself to learn how it works: [citipy Python library](https://pypi.python.org/pypi/citipy).
#
# * Lastly, remember -- this is a challenging activity. Push yourself! If you complete this task, then you can safely say that you've gained a strong mastery of the core foundations of data analytics and it will only go better from here. Good luck!
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Don't modify this cell.
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Don't modify this cell
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
print(cities)
# Out:
# ['qaanaaq', 'caravelas', 'vogan', 'ushuaia', 'new norfolk', 'waipawa', 'saint-philippe', 'ribeira grande', 'esfahan', 'provideniya', 'cape town', 'nikolskoye', 'taolanaro', 'marzuq', 'chokurdakh', 'san patricio', 'frantiskovy lazne', 'coihaique', 'mataura', 'libertador general san martin', 'hithadhoo', 'lompoc', 'punta arenas', 'georgetown', 'moose factory', 'tete', 'chapais', 'aulla', 'thompson', 'puerto ayora', 'hambantota', 'port alfred', 'autazes', 'nuuk', 'pokaran', 'busselton', 'asau', 'maxixe', 'severo-kurilsk', 'coquimbo', 'ostrovnoy', 'rikitea', 'yulara', 'haines junction', 'albany', 'longyearbyen', 'harper', 'tiksi', 'tuktoyaktuk', 'bluff', 'maarianhamina', 'kargasok', 'hilo', 'atuona', 'sapouy', 'dikson', 'khatanga', 'alice springs', 'east london', 'jamestown', 'corabia', 'bengkulu', 'mys shmidta', 'sola', 'brigantine', 'matara', 'vaitupu', 'upernavik', 'illoqqortoormiut', 'rolim de moura', 'bukama', 'pa sang', 'hobart', 'ilulissat', 'beringovskiy', 'yellowknife', 'arraial do cabo', 'barrow', 'dunedin', 'victoria', 'shurugwi', 'tucurui', 'fort saint james', 'sentyabrskiy', 'dengfeng', 'nemuro', 'mahebourg', 'yakeshi', 'lorengau', 'airai', 'berdigestyakh', 'gramoteino', 'praia da vitoria', 'butaritari', 'flinders', 'ixtapa', 'salalah', 'mar del plata', 'buala', 'ishinomaki', 'meulaboh', 'igrim', 'sao filipe', 'ambodifototra', 'ballarat', 'broken hill', 'barentsburg', 'kensington', 'sinnamary', 'aksehir', 'sompeta', 'comodoro rivadavia', 'portobelo', 'wamba', 'port elizabeth', 'jinchang', 'prince rupert', 'codrington', 'sabzevar', 'henties bay', 'ponta do sol', 'faanui', 'kamenskoye', 'boddam', 'tshikapa', 'sao joao da barra', 'yangambi', 'roma', 'castro', 'attawapiskat', 'mehamn', 'alyangula', 'iqaluit', 'bac lieu', 'sundumbili', 'raga', 'norsup', 'tanout', 'dukstas', 'hermanus', 'barra do corda', 'nara', 'avera', 'bredasdorp', 'farafangana', 'coahuayana', 'evanston', 'kruisfontein', 'yumen', 'plettenberg bay', 'burica', 'izmit', 'bandarbeyla', 'paita', 'esperance', 'fortuna', 'cherskiy', 'kavieng', 'araouane', 'tasiilaq', 'kodiak', 'bardiyah', 'isangel', 'shimoda', 'torbay', 'kieta', 'marang', 'kapaa', 'saleaula', 'ekibastuz', 'gollere', 'vaini', 'sitka', 'salinopolis', 'avarua', 'wladyslawowo', 'lavrentiya', 'korla', 'ndjole', 'vorukh', 'marsh harbour', 'santa isabel do rio negro', 'punakha', 'lata', 'vila franca do campo', 'aranos', 'fare', 'gat', 'grand river south east', 'polson', 'panzhihua', 'teneguiban', 'chifeng', 'marienburg', 'moron', 'matagami', 'tsihombe', 'pandan', 'birigui', 'ihosy', 'nakapiripirit', 'puerto del rosario', 'brewster', 'san policarpo', 'campbell river', 'dubbo', 'maniitsoq', 'antrim', 'aguada de pasajeros', 'chara', 'lappeenranta', 'bozeman', 'galesong', 'okolona', 'westport', 'vostok', 'saint-joseph', 'cidreira', 'belushya guba', 'tuytepa', 'geraldton', 'leningradskiy', 'cabo san lucas', 'jiwani', 'presidencia roque saenz pena', 'yar-sale', 'nome', 'christchurch', 'port moresby', 'pathein', 'upata', 'komsomolskiy', 'portland', 'vanino', 'havre-saint-pierre', 'port lincoln', 'iberia', 'nevinnomyssk', 'nouadhibou', 'aklavik', 'amderma', 'agadez', 'valparaiso', 'bethel', 'sechura', 'hamilton', 'skjervoy', 'klaksvik', 'buariki', 'clyde river', 'warmbad', 'kaitangata', 'clarence town', 'taunggyi', 'plaster rock', 'samusu', 'playas', 'taybad', 'turayf', 'kashi', 'trairi', 'mayo', 'auce', 'waimana', 'sesheke', 'sisimiut', 'chuy', 'zhezkazgan', 'pevek', 'atar', 'jaumave', 'san quintin', 'cabedelo', 'liwale', 'skibbereen', 'solnechnyy', 'campo grande', 'shihezi', 'carnarvon', 'mayor pablo lagerenza', 'yambio', 'bolungarvik', 'hasaki', 'tuatapere', 'padang', 'hualmay', 'vallenar', 'kahului', 'puerto colombia', 'khandbari', 'zhuhai', 'souillac', 'balaipungut', 'lingao', 'marystown', 'moerai', 'norman wells', 'bairiki', 'seoul', 'cockburn town', 'uwayl', 'fairbanks', 'maceio', 'lebu', 'dahuk', 'piacabucu', 'fairview', 'poya', 'la sarre', 'bathsheba', 'guangshui', 'bongandanga', 'baruun-urt', 'sao m ...

# %% [markdown]
# A lot of starter code has been generated for you. Use the cell below to play with the data to ensure you know what's happening.

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city in `cities` using a series of successive API calls.
# * OPTIONAL: Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# base url for getting api data
#base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
# example request
#req = requests.get(base_url + f'&q={cities[0]}').json()
#print(req)
# Your code here. A loop maybe? 
#NOTE: API calls can be slow. They can also be limited. Once you have a list try not to rerun all API calls very often. 

city_name=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
lat=[]
lng=[]
max_temp=[]
wind_speed=[]
k = 0    
for index, city in enumerate(cities):
    url = f"http://api.openweathermap.org/data/2.5/weather?q={cities[k]}&units=imperial&appid="+api_key
    response = requests.get(url).json()    
    if response == {"cod":"404","message":"city not found"}:
        print("City not found")
        k=k+1
    else:
        url = f"http://api.openweathermap.org/data/2.5/weather?q={cities[k]}&units=imperial&appid="+api_key
        response = requests.get(url).json()    
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response["wind"]["speed"])
        print(response)
        k = k+1
# Out:
# {'coord': {'lon': -69.3632, 'lat': 77.484}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 4.06, 'feels_like': -10.91, 'temp_min': 4.06, 'temp_max': 4.06, 'pressure': 1029, 'humidity': 59, 'sea_level': 1029, 'grnd_level': 1025}, 'visibility': 10000, 'wind': {'speed': 10.02, 'deg': 67, 'gust': 13.31}, 'clouds': {'all': 100}, 'dt': 1617637381, 'sys': {'country': 'GL', 'sunrise': 1617611042, 'sunset': 1617670541}, 'timezone': -10800, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# {'coord': {'lon': -39.2481, 'lat': -17.7125}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 83.7, 'feels_like': 86.29, 'temp_min': 83.7, 'temp_max': 83.7, 'pressure': 1015, 'humidity': 57, 'sea_level': 1015, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 8.68, 'deg': 160, 'gust': 10.07}, 'clouds': {'all': 100}, 'dt': 1617637382, 'sys': {'country': 'BR', 'sunrise': 1617612232, 'sunset': 1617654900}, 'timezone': -10800, 'id': 3466980, 'name': 'Caravelas', 'cod': 200}
# {'coord': {'lon': 1.5333, 'lat': 6.3333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 87.8, 'feels_like': 99.68, 'temp_min': 87.8, 'temp_max': 87.8, 'pressure': 1009, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 210}, 'clouds': {'all': 20}, 'dt': 1617637382, 'sys': {'type': 1, 'id': 1218, 'country': 'TG', 'sunrise': 1617601814, 'sunset': 1617645746}, 'timezone': 0, 'id': 2363490, 'name': 'Vogan', 'cod': 200}
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 42.8, 'feels_like': 36.97, 'temp_min': 42.8, 'temp_max': 42.8, 'pressure': 1015, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 230}, 'clouds': {'all': 75}, 'dt': 1617637158, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1617620720, 'sunset': 1617660354}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# {'coord': {'lon': 147.0587, 'lat': -42.7826}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 50.41, 'feels_like': 48.45, 'temp_min': 48, 'temp_max': 52, 'pressure': 1022, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 3.29, 'deg': 284, 'gust': 2.98}, 'clouds': {'all': 0}, 'dt': 1617637383, 'sys': {'type': 3, 'id': 2031307, 'country': 'AU', 'sunrise': 1617654794, 'sunset': 1617695694}, 'timezone': 36000, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# {'coord': {'lon': 175.5153, 'lat': -41.4122}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 58.82, 'feels_like': 58.82, 'temp_min': 57, 'temp_max': 61, 'pressure': 1016, 'humidity': 94}, 'visibility': 8000, 'wind': {'speed': 10.36, 'deg': 220}, 'clouds': {'all': 90}, 'dt': 1617637383, 'sys': {'type': 1, 'id': 7358, 'country': 'NZ', 'sunrise': 1617647898, 'sunset': 1617688933}, 'timezone': 43200, 'id': 2206874, 'name': 'Waipawa', 'cod': 200}
# {'coord': {'lon': 55.7679, 'lat': -21.3585}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 74.93, 'feels_like': 75.6, 'temp_min': 68, 'temp_max': 80.6, 'pressure': 1013, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 50}, 'clouds': {'all': 0}, 'dt': 1617637384, 'sys': {'type': 1, 'id': 2127, 'country': 'RE', 'sunrise': 1617589525, 'sunset': 1617632008}, 'timezone': 14400, 'id': 935215, 'name': 'Saint-Philippe', 'cod': 200}
# {'coord': {'lon': -28.7, 'lat': 38.5167}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 64.4, 'feels_like': 64.4, 'temp_min': 64.4, 'temp_max': 64.4, 'pressure': 1010, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 25.32, 'deg': 120}, 'clouds': {'all': 20}, 'dt': 1617637384, 'sys': {'type': 1, 'id': 6883, 'country': 'PT', 'sunrise': 1617607991, 'sunset': 1617654079}, 'timezone': 0, 'id': 3372707, 'name': 'Ribeira Grande', 'cod': 200}
# {'coord': {'lon': 51.6776, 'lat': 32.6572}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 66.2, 'feels_like': 62.89, 'temp_min': 66.2, 'temp_max': 66.2, 'pressure': 1019, 'humidity': 8}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 9, 'gust': 8.34}, 'clouds': {'all': 20}, 'dt': 1617637204, 'sys': {'type': 1, 'id': 7460, 'country': 'IR', 'sunrise': 1617588967, 'sunset': 1617634529}, 'timezone': 16200, 'id': 418863, 'name': 'Isfahan', 'cod': 200}
# {'coord': {'lon': -173.3, 'lat': 64.3833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 1.22, 'feels_like': -13.54, 'temp_min': 1.22, 'temp_max': 1.22, 'pressure': 1025, 'humidity': 93, 'sea_level': 1025, 'grnd_level': 1025}, 'visibility': 10000, 'wind': {'speed': 8.97, 'deg': 56, 'gust': 10.65}, 'clouds': {'all': 100}, 'dt': 1617637385, 'sys': {'country': 'RU', 'sunrise': 1617726624, 'sunset': 1617777605}, 'timezone': 43200, 'id': 4031574, 'name': 'Provideniya', 'cod': 200}
# {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 63.79, 'feels_like': 63.07, 'temp_min': 61, 'temp_max': 66.2, 'pressure': 1019, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 21.85, 'deg': 180}, 'clouds': {'all': 20}, 'dt': 1617637174, 'sys': {'type': 1, 'id': 1899, 'country': 'ZA', 'sunrise': 1617598880, 'sunset': 1617640575}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# {'coord': {'lon': 30.7861, 'lat': 59.7035}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 46.47, 'feels_like': 42.06, 'temp_min': 46, 'temp_max': 46.99, 'pressure': 986, 'humidity': 53}, 'visibility': 10000, 'wind': {'speed': 8.95, 'deg': 190}, 'clouds': {'all': 20}, 'dt': 1617637385, 'sys': {'type': 1, 'id': 8926, 'country': 'RU', 'sunrise': 1617592218, 'sunset': 1617641304}, 'timezone': 10800, 'id': 546105, 'name': 'Nikolskoye', 'cod': 200}
# City not found
# {'coord': {'lon': 46.4667, 'lat': 14.4}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 76.6, 'feels_like': 75.27, 'temp_min': 76.6, 'temp_max': 76.6, 'pressure': 1014, 'humidity': 28, 'sea_level': 1014, 'grnd_level': 890}, 'visibility': 10000, 'wind': {'speed': 5.82, 'deg': 149, 'gust': 6.8}, 'clouds': {'all': 7}, 'dt': 1617637386, 'sys': {'country': 'YE', 'sunrise': 1617590814, 'sunset': 1617635183}, 'timezone': 10800, 'id': 72181, 'name': 'Marzuq', 'cod': 200}
# {'coord': {'lon': 147.9167, 'lat': 70.6333}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': -31.36, 'feels_like': -31.36, 'temp_min': -31.36, 'temp_max': -31.36, 'pressure': 1030, 'humidity': 99, 'sea_level': 1030, 'grnd_level': 1026}, 'visibility': 10000, 'wind': {'speed': 1.32, 'deg': 360, 'gust': 1.95}, 'clouds': {'all': 42}, 'dt': 1617637386, 'sys': {'country': 'RU', 'sunrise': 1617648347, 'sunset': 1617701728}, 'timezone': 39600, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}
# {'coord': {'lon': -97.5169, 'lat': 28.017}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 74.66, 'feels_like': 75.49, 'temp_min': 71.6, 'temp_max': 77, 'pressure': 1019, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 160}, 'clouds': {'all': 75}, 'dt': 1617637387, 'sys': {'type': 1, 'id': 3705, 'country': 'US', 'sunrise': 1617624918, 'sunset': 1617670177}, 'timezone': -18000, 'id': 4726521, 'name': 'San Patricio', 'cod': 200}
# {'coord': {'lon': 12.3517, 'lat': 50.1203}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 31.69, 'feels_like': 26.71, 'temp_min': 30.99, 'temp_max': 33.01, 'pressure': 1002, 'humidity': 96}, 'visibility': 414, 'wind': {'speed': 5.01, 'deg': 342, 'gust': 10}, 'snow': {'1h': 0.29}, 'clouds': {'all': 100}, 'dt': 1617637387, 'sys': {'type': 3, 'id': 2017954, 'country': 'CZ', 'sunrise': 1617597494, 'sunset': 1617644875}, 'timezone': 7200, 'id': 3076136, 'name': 'Františkovy Lázně', 'cod': 200}
# {'coord': {'lon': -72.0662, 'lat': -45.5752}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 57.2, 'feels_like': 56.25, 'temp_min': 57.2, 'temp_max': 57.2, 'pressure': 1013, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 220}, 'clouds': {'all': 90}, 'dt': 1617637388, 'sys': {'type': 1, 'id': 8491, 'country': 'CL', 'sunrise': 1617621087, 'sunset': 1617661794}, 'timezone': -14400, 'id': 3894426, 'name': 'Coyhaique', 'cod': 200}
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 48.99, 'feels_like': 47.03, 'temp_min': 48.99, 'temp_max': 48.99, 'pressure': 1015, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 325, 'gust': 10}, 'clouds': {'all': 5}, 'dt': 1617637388, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1617649720, 'sunset': 1617690303}, 'timezone': 43200, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# {'coord': {'lon': -64.7876, 'lat': -23.8064}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.01, 'feels_like': 84.11, 'temp_min': 80.01, 'temp_max': 80.01, 'pressure': 1010, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 2.71, 'deg': 113, 'gust': 3.74}, 'clouds': {'all': 99}, 'dt': 1617637389, 'sys': {'type': 3, 'id': 2034051, 'country': 'AR', 'sunrise': 1617618536, 'sunset': 1617660852}, 'timezone': -10800, 'id': 3846915, 'name': 'Libertador General San Martín', 'cod': 200}
# {'coord': {'lon': 73.0833, 'lat': -0.6}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 84.2, 'feels_like': 91.24, 'temp_min': 84.2, 'temp_max': 84.2, 'pressure': 1011, 'humidity': 71, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 15.19, 'deg': 306, 'gust': 16.67}, 'rain': {'1h': 1.4404}, 'clouds': {'all': 73}, 'dt': 1617637389, 'sys': {'country': 'MV', 'sunrise': 1617584827, 'sunset': 1617628397}, 'timezone': 18000, 'id': 1282256, 'name': 'Hithadhoo', 'cod': 200}
# {'coord': {'lon': -120.4579, 'lat': 34.6391}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 51.21, 'feels_like': 49.6, 'temp_min': 50, 'temp_max': 51.8, 'pressure': 1019, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 320}, 'clouds': {'all': 60}, 'dt': 1617637390, 'sys': {'type': 1, 'id': 4747, 'country': 'US', 'sunrise': 1617630161, 'sunset': 1617675943}, 'timezone': -25200, 'id': 5367788, 'name': 'Lompoc', 'cod': 200}
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 46.2, 'feels_like': 44.96, 'temp_min': 46, 'temp_max': 46.4, 'pressure': 1016, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 190}, 'clouds': {'all': 40}, 'dt': 1617637390, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1617621236, 'sunset': 1617661093}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# {'coord': {'lon': 100.3354, 'lat': 5.4112}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 83.05, 'feels_like': 90.81, 'temp_min': 82, 'temp_max': 84.2, 'pressure': 1009, 'humidity': 78}, 'visibility': 7000, 'wind': {'speed': 4.61, 'deg': 80}, 'rain': {'1h': 0.58}, 'clouds': {'all': 40}, 'dt': 1617637146, 'sys': {'type': 1, 'id': 9429, 'country': 'MY', 'sunrise': 1617578133, 'sunset': 1617622012}, 'timezone': 28800, 'id': 1735106, 'name': 'George Town', 'cod': 200}
# {'coord': {'lon': -80.6094, 'lat': 51.2585}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 37.4, 'feels_like': 31.39, 'temp_min': 37.4, 'temp_max': 37.4, 'pressure': 1027, 'humidity': 60}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 70}, 'clouds': {'all': 1}, 'dt': 1617637391, 'sys': {'type': 1, 'id': 860, 'country': 'CA', 'sunrise': 1617619688, 'sunset': 1617667293}, 'timezone': -14400, 'id': 6078372, 'name': 'Moose Factory', 'cod': 200}
# {'coord': {'lon': 33.5867, 'lat': -16.1564}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 89.6, 'feels_like': 91.11, 'temp_min': 89.6, 'temp_max': 89.6, 'pressure': 1013, 'humidity': 43}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 90}, 'clouds': {'all': 20}, 'dt': 1617637391, 'sys': {'type': 1, 'id': 2212, 'country': 'MZ', 'sunrise': 1617594707, 'sunset': 1617637471}, 'timezone': 7200, 'id': 1026014, 'name': 'Tete', 'cod': 200}
# {'coord': {'lon': -74.8492, 'lat': 49.7834}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 35.6, 'feels_like': 27.05, 'temp_min': 35.6, 'temp_max': 35.6, 'pressure': 1022, 'humidity': 41}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 360, 'gust': 18.41}, 'clouds': {'all': 90}, 'dt': 1617637392, 'sys': {'type': 1, 'id': 859, 'country': 'CA', 'sunrise': 1617618414, 'sunset': 1617665802}, 'timezone': -14400, 'id': 5919850, 'name': 'Chapais', 'cod': 200}
# {'coord': {'lon': 9.9678, 'lat': 44.2146}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 57.36, 'feels_like': 55.44, 'temp_min': 55.99, 'temp_max': 59, 'pressure': 1010, 'humidity': 56}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 247, 'gust': 13}, 'clouds': {'all': 38}, 'dt': 1617637392, 'sys': {'type': 3, 'id': 2016110, 'country': 'IT', 'sunrise': 1617598433, 'sunset': 1617645080}, 'timezone': 7200, 'id': 3182686, 'name': 'Aulla', 'cod': 200}
# {'coord': {'lon': -97.8558, 'lat': 55.7435}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 32, 'feels_like': 27.45, 'temp_min': 32, 'temp_max': 32, 'pressure': 1002, 'humidity': 100}, 'visibility': 805, 'wind': {'speed': 4.61, 'deg': 120}, 'snow': {'1h': 0.76}, 'clouds': {'all': 90}, 'dt': 1617637393, 'sys': {'type': 1, 'id': 935, 'country': 'CA', 'sunrise': 1617623445, 'sunset': 1617671813}, 'timezone': -18000, 'id': 6165406, 'name': 'Thompson', 'cod': 200}
# {'coord': {'lon': -90.3518, 'lat': -0.7393}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.22, 'feels_like': 84.42, 'temp_min': 80.01, 'temp_max': 80.6, 'pressure': 1010, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 50}, 'clouds': {'all': 40}, 'dt': 1617637393, 'sys': {'type': 1, 'id': 8521, 'country': 'EC', 'sunrise': 1617624047, 'sunset': 1617667609}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# {'coord': {'lon': 81.1185, 'lat': 6.1241}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 89.31, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1009, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 70}, 'clouds': {'all': 0}, 'dt': 1617637393, 'sys': {'type': 1, 'id': 9124, 'country': 'LK', 'sunrise': 1617582725, 'sunset': 1617626642}, 'timezone': 19800, 'id': 1244926, 'name': 'Hambantota', 'cod': 200}
# {'coord': {'lon': 26.891, 'lat': -33.5906}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 64.83, 'feels_like': 64.87, 'temp_min': 64.83, 'temp_max': 64.83, 'pressure': 1020, 'humidity': 82, 'sea_level': 1020, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 12.97, 'deg': 148, 'gust': 14.61}, 'clouds': {'all': 100}, 'dt': 1617637394, 'sys': {'country': 'ZA', 'sunrise': 1617596835, 'sunset': 1617638556}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# {'coord': {'lon': -59.1306, 'lat': -3.5797}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 85.15, 'feels_like': 94.66, 'temp_min': 85.15, 'temp_max': 85.15, 'pressure': 1009, 'humidity': 74, 'sea_level': 1009, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 4.27, 'deg': 87, 'gust': 9.37}, 'rain': {'1h': 3.158}, 'clouds': {'all': 100}, 'dt': 1617637394, 'sys': {'country': 'BR', 'sunrise': 1617616629, 'sunset': 1617660044}, 'timezone': -14400, 'id': 3406948, 'name': 'Autazes', 'cod': 200}
# {'coord': {'lon': -51.7216, 'lat': 64.1835}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 35.29, 'feels_like': 23.54, 'temp_min': 35.01, 'temp_max': 35.6, 'pressure': 1031, 'humidity': 93}, 'visibility': 5000, 'wind': {'speed': 23.02, 'deg': 180}, 'rain': {'1h': 0.86}, 'clouds': {'all': 90}, 'dt': 1617637373, 'sys': {'type': 1, 'id': 86, 'country': 'GL', 'sunrise': 1617611367, 'sunset': 1617661750}, 'timezone': -7200, 'id': 3421319, 'name': 'Nuuk', 'cod': 200}
# {'coord': {'lon': 71.9167, 'lat': 26.9167}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 90.25, 'feels_like': 86.16, 'temp_min': 90.25, 'temp_max': 90.25, 'pressure': 1006, 'humidity': 14, 'sea_level': 1006, 'grnd_level': 980}, 'visibility': 10000, 'wind': {'speed': 11.36, 'deg': 240, 'gust': 22.62}, 'clouds': {'all': 49}, 'dt': 1617637395, 'sys': {'country': 'IN', 'sunrise': 1617584323, 'sunset': 1617629460}, 'timezone': 19800, 'id': 1259460, 'name': 'Pokaran', 'cod': 200}
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 59.63, 'feels_like': 59.72, 'temp_min': 59, 'temp_max': 60.01, 'pressure': 1013, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 3.33, 'deg': 98, 'gust': 3.83}, 'clouds': {'all': 1}, 'dt': 1617637395, 'sys': {'type': 3, 'id': 2008303, 'country': 'AU', 'sunrise': 1617575600, 'sunset': 1617617347}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# {'coord': {'lon': 26.4, 'lat': 46.4333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 48.99, 'feels_like': 45.03, 'temp_min': 48.99, 'temp_max': 48.99, 'pressure': 1005, 'humidity': 30}, 'visibility': 10000, 'wind': {'speed': 9.28, 'deg': 262, 'gust': 19.35}, 'clouds': {'all': 16}, 'dt': 1617637396, 'sys': {'type': 3, 'id': 2033571, 'country': 'RO', 'sunrise': 1617594366, 'sunset': 1617641261}, 'timezone': 10800, 'id': 686090, 'name': 'Asău', 'cod': 200}
# {'coord': {'lon': 35.3472, 'lat': -23.8597}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 81.03, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1016, 'humidity': 47}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 150}, 'clouds': {'all': 20}, 'dt': 1617637396, 'sys': {'type': 1, 'id': 2200, 'country': 'MZ', 'sunrise': 1617594499, 'sunset': 1617636834}, 'timezone': 7200, 'id': 1039536, 'name': 'Maxixe', 'cod': 200}
# {'coord': {'lon': 156.125, 'lat': 50.6789}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 26.73, 'feels_like': 16.09, 'temp_min': 26.73, 'temp_max': 26.73, 'pressure': 1015, 'humidity': 80, 'sea_level': 1015, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 12.15, 'deg': 288, 'gust': 15.95}, 'clouds': {'all': 87}, 'dt': 1617637397, 'sys': {'country': 'RU', 'sunrise': 1617649270, 'sunset': 1617696867}, 'timezone': 39600, 'id': 2121385, 'name': "Severo-Kuril'sk", 'cod': 200}
# {'coord': {'lon': -71.3436, 'lat': -29.9533}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 68, 'feels_like': 67.14, 'temp_min': 68, 'temp_max': 68, 'pressure': 1015, 'humidity': 56}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 290}, 'clouds': {'all': 0}, 'dt': 1617637368, 'sys': {'type': 1, 'id': 8514, 'country': 'CL', 'sunrise': 1617620300, 'sunset': 1617662234}, 'timezone': -14400, 'id': 3893629, 'name': 'Coquimbo', 'cod': 200}
# {'coord': {'lon': 39.5131, 'lat': 68.0531}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 34.2, 'feels_like': 22.1, 'temp_min': 34.2, 'temp_max': 34.2, 'pressure': 982, 'humidity': 86, 'sea_level': 982, 'grnd_level': 979}, 'visibility': 10000, 'wind': {'speed': 22.97, 'deg': 182, 'gust': 37.96}, 'clouds': {'all': 100}, 'dt': 1617637397, 'sys': {'country': 'RU', 'sunrise': 1617588810, 'sunset': 1617640523}, 'timezone': 10800, 'id': 556268, 'name': 'Ostrovnoy', 'cod': 200}
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 77.94, 'feels_like': 78.39, 'temp_min': 77.94, 'temp_max': 77.94, 'pressure': 1008, 'humidity': 63, 'sea_level': 1008, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 8.55, 'deg': 254, 'gust': 9.71}, 'clouds': {'all': 48}, 'dt': 1617637398, 'sys': {'country': 'PF', 'sunrise': 1617635364, 'sunset': 1617677705}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# {'coord': {'lon': 130.9889, 'lat': -25.2406}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 69.8, 'feels_like': 68.36, 'temp_min': 69.8, 'temp_max': 69.8, 'pressure': 1017, 'humidity': 40}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 140}, 'clouds': {'all': 0}, 'dt': 1617637398, 'sys': {'type': 1, 'id': 9487, 'country': 'AU', 'sunrise': 1617658004, 'sunset': 1617700195}, 'timezone': 34200, 'id': 6355222, 'name': 'Yulara', 'cod': 200}
# {'coord': {'lon': -137.5108, 'lat': 60.7522}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 26.6, 'feels_like': 14.23, 'temp_min': 26.6, 'temp_max': 26.6, 'pressure': 1011, 'humidity': 63}, 'visibility': 135, 'wind': {'speed': 16.11, 'deg': 330, 'gust': 24.16}, 'snow': {'1h': 0.44}, 'clouds': {'all': 99}, 'dt': 1617637399, 'sys': {'type': 1, 'id': 287, 'country': 'CA', 'sunrise': 1617632397, 'sunset': 1617681891}, 'timezone': -25200, 'id': 5969025, 'name': 'Haines Junction', 'cod': 200}
# {'coord': {'lon': -73.9662, 'lat': 42.6001}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 53.01, 'feels_like': 49.46, 'temp_min': 50, 'temp_max': 55.99, 'pressure': 1011, 'humidity': 31}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 306, 'gust': 11.99}, 'clouds': {'all': 23}, 'dt': 1617637399, 'sys': {'type': 3, 'id': 19530, 'country': 'US', 'sunrise': 1617618640, 'sunset': 1617665153}, 'timezone': -14400, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# {'coord': {'lon': 15.6401, 'lat': 78.2186}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 17.6, 'feels_like': 1.26, 'temp_min': 17.6, 'temp_max': 17.6, 'pressure': 1011, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 19.57, 'deg': 40}, 'clouds': {'all': 75}, 'dt': 1617637400, 'sys': {'type': 1, 'id': 1663, 'country': 'SJ', 'sunrise': 1617590174, 'sunset': 1617650617}, 'timezone': 7200, 'id': 2729907, 'name': 'Longyearbyen', 'cod': 200}
# {'coord': {'lon': -7.7169, 'lat': 4.375}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 84.18, 'feels_like': 90.54, 'temp_min': 84.18, 'temp_max': 84.18, 'pressure': 1009, 'humidity': 69, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 6.4, 'deg': 184, 'gust': 6.76}, 'clouds': {'all': 99}, 'dt': 1617637400, 'sys': {'country': 'LR', 'sunrise': 1617604085, 'sunset': 1617647914}, 'timezone': 0, 'id': 2276492, 'name': 'Harper', 'cod': 200}
# {'coord': {'lon': 128.8694, 'lat': 71.6872}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': -19.41, 'feels_like': -31.61, 'temp_min': -19.41, 'temp_max': -19.41, 'pressure': 1031, 'humidity': 99, 'sea_level': 1031, 'grnd_level': 1025}, 'visibility': 6696, 'wind': {'speed': 4.14, 'deg': 230, 'gust': 3.85}, 'clouds': {'all': 45}, 'dt': 1617637400, 'sys': {'country': 'RU', 'sunrise': 1617652573, 'sunset': 1617706643}, 'timezone': 32400, 'id': 2015306, 'name': 'Tiksi', 'cod': 200}
# {'coord': {'lon': -133.0374, 'lat': 69.4541}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': -5.8, 'feels_like': -31.97, 'temp_min': -5.8, 'temp_max': -5.8, 'pressure': 1012, 'humidity': 84}, 'visibility': 805, 'wind': {'speed': 25.32, 'deg': 340, 'gust': 32.21}, 'clouds': {'all': 90}, 'dt': 1617637401, 'sys': {'type': 1, 'id': 942, 'country': 'CA', 'sunrise': 1617629763, 'sunset': 1617682378}, 'timezone': -21600, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 48.99, 'feels_like': 47.03, 'temp_min': 48.99, 'temp_max': 48.99, 'pressure': 1015, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 325, 'gust': 10}, 'clouds': {'all': 86}, 'dt': 1617637401, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1617649868, 'sunset': 1617690410}, 'timezone': 43200, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# {'coord': {'lon': 19.9348, 'lat': 60.0973}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 35.6, 'feels_like': 29.19, 'temp_min': 35.6, 'temp_max': 35.6, 'pressure': 979, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 230}, 'clouds': {'all': 20}, 'dt': 1617637402, 'sys': {'type': 1, 'id': 1347, 'country': 'AX', 'sunrise': 1617594771, 'sunset': 1617643958}, 'timezone': 10800, 'id': 3041732, 'name': 'Mariehamn', 'cod': 200}
# {'coord': {'lon': 80.8572, 'lat': 59.0556}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 34.88, 'feels_like': 26.02, 'temp_min': 34.88, 'temp_max': 34.88, 'pressure': 1009, 'humidity': 89, 'sea_level': 1009, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 12.97, 'deg': 149, 'gust': 28.74}, 'clouds': {'all': 100}, 'dt': 1617637402, 'sys': {'country': 'RU', 'sunrise': 1617580299, 'sunset': 1617629194}, 'timezone': 25200, 'id': 1504382, 'name': 'Kargasok', 'cod': 200}
# {'coord': {'lon': -155.09, 'lat': 19.7297}, 'weather': [{'id': 502, 'main': 'Rain', 'description': 'heavy intensity rain', 'icon': '10n'}, {'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 66.29, 'feels_like': 66.52, 'temp_min': 62.01, 'temp_max': 69.8, 'pressure': 1019, 'humidity': 83}, 'visibility': 805, 'wind': {'speed': 10.36, 'deg': 260}, 'rain': {'1h': 3.68}, 'clouds': {'all': 90}, 'dt': 1617637403, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1617639003, 'sunset': 1617683721}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# {'coord': {'lon': -139.0333, 'lat': -9.8}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.04, 'feels_like': 84.18, 'temp_min': 80.04, 'temp_max': 80.04, 'pressure': 1011, 'humidity': 79, 'sea_level': 1011, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 7.81, 'deg': 76, 'gust': 7.9}, 'clouds': {'all': 42}, 'dt': 1617637403, 'sys': {'country': 'PF', 'sunrise': 1617635968, 'sunset': 1617679051}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# {'coord': {'lon': -1.7736, 'lat': 11.5544}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 105.49, 'feels_like': 98.8, 'temp_min': 105.49, 'temp_max': 105.49, 'pressure': 1004, 'humidity': 6, 'sea_level': 1004, 'grnd_level': 968}, 'visibility': 10000, 'wind': {'speed': 5.21, 'deg': 77, 'gust': 4.47}, 'clouds': {'all': 1}, 'dt': 1617637404, 'sys': {'country': 'BF', 'sunrise': 1617602466, 'sunset': 1617646681}, 'timezone': 0, 'id': 2355869, 'name': 'Sapouy', 'cod': 200}
# {'coord': {'lon': 80.5464, 'lat': 73.5069}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 6.03, 'feels_like': -3.17, 'temp_min': 6.03, 'temp_max': 6.03, 'pressure': 1010, 'humidity': 96, 'sea_level': 1010, 'grnd_level': 1004}, 'visibility': 1961, 'wind': {'speed': 4.81, 'deg': 136, 'gust': 4.74}, 'clouds': {'all': 97}, 'dt': 1617637404, 'sys': {'country': 'RU', 'sunrise': 1617577408, 'sunset': 1617632234}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# {'coord': {'lon': 102.5, 'lat': 71.9667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 5.16, 'feels_like': -9.87, 'temp_min': 5.16, 'temp_max': 5.16, 'pressure': 1015, 'humidity': 84, 'sea_level': 1015, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 10.45, 'deg': 148, 'gust': 21.54}, 'clouds': {'all': 74}, 'dt': 1617637406, 'sys': {'country': 'RU', 'sunrise': 1617572708, 'sunset': 1617626398}, 'timezone': 25200, 'id': 2022572, 'name': 'Khatanga', 'cod': 200}
# {'coord': {'lon': 133.8833, 'lat': -23.7}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 68.34, 'feels_like': 67.46, 'temp_min': 66.2, 'temp_max': 70, 'pressure': 1017, 'humidity': 55}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 132, 'gust': 7.31}, 'clouds': {'all': 0}, 'dt': 1617637406, 'sys': {'type': 1, 'id': 9483, 'country': 'AU', 'sunrise': 1617657262, 'sunset': 1617699548}, 'timezone': 34200, 'id': 2077895, 'name': 'Alice Springs', 'cod': 200}
# {'coord': {'lon': 27.9116, 'lat': -33.0153}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 64.4, 'feels_like': 65.25, 'temp_min': 64.4, 'temp_max': 64.4, 'pressure': 1019, 'humidity': 100}, 'visibility': 2800, 'wind': {'speed': 4.61, 'deg': 140}, 'rain': {'1h': 0.12}, 'clouds': {'all': 90}, 'dt': 1617637406, 'sys': {'type': 1, 'id': 1912, 'country': 'ZA', 'sunrise': 1617596570, 'sunset': 1617638331}, 'timezone': 7200, 'id': 1006984, 'name': 'East London', 'cod': 200}
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 54.68, 'feels_like': 51.73, 'temp_min': 50, 'temp_max': 57.99, 'pressure': 1021, 'humidity': 40}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 130}, 'clouds': {'all': 1}, 'dt': 1617637407, 'sys': {'type': 1, 'id': 4588, 'country': 'US', 'sunrise': 1617619929, 'sunset': 1617666392}, 'timezone': -14400, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# {'coord': {'lon': 24.5, 'lat': 43.7833}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 53.6, 'feels_like': 51.39, 'temp_min': 53.6, 'temp_max': 53.6, 'pressure': 1013, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 270}, 'clouds': {'all': 20}, 'dt': 1617637407, 'sys': {'type': 1, 'id': 6369, 'country': 'RO', 'sunrise': 1617594973, 'sunset': 1617641565}, 'timezone': 10800, 'id': 680897, 'name': 'Corabia', 'cod': 200}
# {'coord': {'lon': 102.2655, 'lat': -3.8004}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 75.99, 'feels_like': 77.47, 'temp_min': 75.99, 'temp_max': 75.99, 'pressure': 1012, 'humidity': 89, 'sea_level': 1012, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 4.83, 'deg': 13, 'gust': 6.44}, 'clouds': {'all': 89}, 'dt': 1617637408, 'sys': {'country': 'ID', 'sunrise': 1617577905, 'sunset': 1617621313}, 'timezone': 25200, 'id': 1649150, 'name': 'Bengkulu', 'cod': 200}
# City not found
# {'coord': {'lon': 167.55, 'lat': -13.8833}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 81.1, 'feels_like': 85.33, 'temp_min': 81.1, 'temp_max': 81.1, 'pressure': 1008, 'humidity': 73, 'sea_level': 1008, 'grnd_level': 996}, 'visibility': 10000, 'wind': {'speed': 11.81, 'deg': 107, 'gust': 12.53}, 'clouds': {'all': 14}, 'dt': 1617637408, 'sys': {'country': 'VU', 'sunrise': 1617648899, 'sunset': 1617691755}, 'timezone': 39600, 'id': 2134814, 'name': 'Sola', 'cod': 200}
# {'coord': {'lon': -74.3646, 'lat': 39.4101}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 60.53, 'feels_like': 57.56, 'temp_min': 57.99, 'temp_max': 63, 'pressure': 1016, 'humidity': 27}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 340, 'gust': 28.77}, 'clouds': {'all': 1}, 'dt': 1617637409, 'sys': {'type': 1, 'id': 3222, 'country': 'US', 'sunrise': 1617618896, 'sunset': 1617665088}, 'timezone': -14400, 'id': 4500920, 'name': 'Brigantine', 'cod': 200}
# {'coord': {'lon': 80.5353, 'lat': 5.9485}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 78.44, 'feels_like': 79.99, 'temp_min': 78.44, 'temp_max': 78.44, 'pressure': 1010, 'humidity': 85, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 5.55, 'deg': 297, 'gust': 6.49}, 'clouds': {'all': 32}, 'dt': 1617637409, 'sys': {'country': 'LK', 'sunrise': 1617582870, 'sunset': 1617626777}, 'timezone': 19800, 'id': 1235846, 'name': 'Matara', 'cod': 200}
# City not found
# {'coord': {'lon': -56.1549, 'lat': 72.7868}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -1.26, 'feels_like': -17.77, 'temp_min': -1.26, 'temp_max': -1.26, 'pressure': 1034, 'humidity': 82, 'sea_level': 1034, 'grnd_level': 1034}, 'visibility': 10000, 'wind': {'speed': 10.33, 'deg': 172, 'gust': 14.07}, 'clouds': {'all': 100}, 'dt': 1617637410, 'sys': {'country': 'GL', 'sunrise': 1617610356, 'sunset': 1617664889}, 'timezone': -7200, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# City not found
# City not found
# {'coord': {'lon': 25.85, 'lat': -9.2}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 76.05, 'feels_like': 77.4, 'temp_min': 76.05, 'temp_max': 76.05, 'pressure': 1009, 'humidity': 86, 'sea_level': 1009, 'grnd_level': 943}, 'visibility': 10000, 'wind': {'speed': 1.59, 'deg': 60, 'gust': 2.19}, 'rain': {'1h': 0.63}, 'clouds': {'all': 60}, 'dt': 1617637410, 'sys': {'country': 'CD', 'sunrise': 1617596381, 'sunset': 1617639509}, 'timezone': 7200, 'id': 217834, 'name': 'Bukama', 'cod': 200}
# {'coord': {'lon': 98.9394, 'lat': 18.5262}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 71.87, 'feels_like': 72.66, 'temp_min': 71.6, 'temp_max': 72, 'pressure': 1014, 'humidity': 83}, 'visibility': 8000, 'wind': {'speed': 16.11, 'deg': 360}, 'clouds': {'all': 75}, 'dt': 1617637411, 'sys': {'type': 1, 'id': 9244, 'country': 'TH', 'sunrise': 1617578108, 'sunset': 1617622707}, 'timezone': 25200, 'id': 1151528, 'name': 'Pa Sang', 'cod': 200}
# {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 50.74, 'feels_like': 49.6, 'temp_min': 46.99, 'temp_max': 52, 'pressure': 1022, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 320}, 'clouds': {'all': 0}, 'dt': 1617637411, 'sys': {'type': 1, 'id': 9545, 'country': 'AU', 'sunrise': 1617654733, 'sunset': 1617695624}, 'timezone': 36000, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# {'coord': {'lon': -51.1, 'lat': 69.2167}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 17.6, 'feels_like': 8.22, 'temp_min': 17.6, 'temp_max': 17.6, 'pressure': 1034, 'humidity': 86}, 'visibility': 9000, 'wind': {'speed': 6.91, 'deg': 20}, 'clouds': {'all': 75}, 'dt': 1617637412, 'sys': {'type': 1, 'id': 165, 'country': 'GL', 'sunrise': 1617610221, 'sunset': 1617662598}, 'timezone': -7200, 'id': 3423146, 'name': 'Ilulissat', 'cod': 200}
# {'coord': {'lon': 179.3167, 'lat': 63.05}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 7.84, 'feels_like': -9.4, 'temp_min': 7.84, 'temp_max': 7.84, 'pressure': 1019, 'humidity': 95, 'sea_level': 1019, 'grnd_level': 1016}, 'visibility': 105, 'wind': {'speed': 15.1, 'deg': 19, 'gust': 25.66}, 'snow': {'1h': 1.02}, 'clouds': {'all': 100}, 'dt': 1617637412, 'sys': {'country': 'RU', 'sunrise': 1617642418, 'sunset': 1617692588}, 'timezone': 43200, 'id': 2126710, 'name': 'Beringovskiy', 'cod': 200}
# {'coord': {'lon': -114.3525, 'lat': 62.456}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 16.61, 'feels_like': 4.42, 'temp_min': 15.01, 'temp_max': 19.99, 'pressure': 1006, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 100}, 'clouds': {'all': 75}, 'dt': 1617637381, 'sys': {'type': 1, 'id': 1007, 'country': 'CA', 'sunrise': 1617626623, 'sunset': 1617676552}, 'timezone': -21600, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# {'coord': {'lon': -42.0278, 'lat': -22.9661}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 81.37, 'feels_like': 84.38, 'temp_min': 80.6, 'temp_max': 82.4, 'pressure': 1018, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 360}, 'clouds': {'all': 40}, 'dt': 1617637413, 'sys': {'type': 1, 'id': 8326, 'country': 'BR', 'sunrise': 1617613048, 'sunset': 1617655418}, 'timezone': -10800, 'id': 3471451, 'name': 'Arraial do Cabo', 'cod': 200}
# {'coord': {'lon': -156.7887, 'lat': 71.2906}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': -7.6, 'feels_like': -18.78, 'temp_min': -7.6, 'temp_max': -7.6, 'pressure': 1022, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 270}, 'clouds': {'all': 40}, 'dt': 1617637413, 'sys': {'type': 1, 'id': 7649, 'country': 'US', 'sunrise': 1617634924, 'sunset': 1617688615}, 'timezone': -28800, 'id': 5880054, 'name': 'Barrow', 'cod': 200}
# {'coord': {'lon': 170.5036, 'lat': -45.8742}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 50.9, 'feels_like': 49.12, 'temp_min': 50, 'temp_max': 52, 'pressure': 1000, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 90, 'gust': 1.99}, 'clouds': {'all': 76}, 'dt': 1617637414, 'sys': {'type': 3, 'id': 2031989, 'country': 'NZ', 'sunrise': 1617649310, 'sunset': 1617689926}, 'timezone': 43200, 'id': 2191562, 'name': 'Dunedin', 'cod': 200}
# {'coord': {'lon': 114.1577, 'lat': 22.2855}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 71.01, 'feels_like': 71.71, 'temp_min': 63, 'temp_max': 73, 'pressure': 1018, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 28, 'gust': 3}, 'clouds': {'all': 79}, 'dt': 1617637188, 'sys': {'type': 3, 'id': 2035800, 'country': 'HK', 'sunrise': 1617574343, 'sunset': 1617619168}, 'timezone': 28800, 'id': 1819729, 'name': 'Hong Kong', 'cod': 200}
# {'coord': {'lon': 30.0059, 'lat': -19.6702}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 66.97, 'feels_like': 65.53, 'temp_min': 66.97, 'temp_max': 66.97, 'pressure': 1015, 'humidity': 46, 'sea_level': 1015, 'grnd_level': 856}, 'visibility': 10000, 'wind': {'speed': 5.93, 'deg': 147, 'gust': 12.1}, 'clouds': {'all': 0}, 'dt': 1617637414, 'sys': {'country': 'ZW', 'sunrise': 1617595662, 'sunset': 1617638234}, 'timezone': 7200, 'id': 881164, 'name': 'Shurugwi', 'cod': 200}
# {'coord': {'lon': -49.6725, 'lat': -3.7661}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 87.04, 'feels_like': 95.31, 'temp_min': 87.04, 'temp_max': 87.04, 'pressure': 1009, 'humidity': 65, 'sea_level': 1009, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 5.73, 'deg': 81, 'gust': 9.73}, 'clouds': {'all': 90}, 'dt': 1617637415, 'sys': {'country': 'BR', 'sunrise': 1617614365, 'sunset': 1617657770}, 'timezone': -10800, 'id': 3385935, 'name': 'Tucuruí', 'cod': 200}
# {'coord': {'lon': -124.25, 'lat': 54.4333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 32.83, 'feels_like': 29.7, 'temp_min': 32.83, 'temp_max': 32.83, 'pressure': 1019, 'humidity': 71, 'sea_level': 1019, 'grnd_level': 935}, 'visibility': 10000, 'wind': {'speed': 3.42, 'deg': 204, 'gust': 5.35}, 'clouds': {'all': 97}, 'dt': 1617637415, 'sys': {'country': 'CA', 'sunrise': 1617629887, 'sunset': 1617678037}, 'timezone': -25200, 'id': 5881688, 'name': 'Fort Saint James', 'cod': 200}
# City not found
# {'coord': {'lon': 113.0281, 'lat': 34.4553}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 42.03, 'feels_like': 42.03, 'temp_min': 42.03, 'temp_max': 42.03, 'pressure': 1022, 'humidity': 67, 'sea_level': 1022, 'grnd_level': 977}, 'visibility': 10000, 'wind': {'speed': 1.9, 'deg': 169, 'gust': 2.13}, 'clouds': {'all': 58}, 'dt': 1617637416, 'sys': {'country': 'CN', 'sunrise': 1617574185, 'sunset': 1617619869}, 'timezone': 28800, 'id': 1813016, 'name': 'Songyang', 'cod': 200}
# {'coord': {'lon': 145.575, 'lat': 43.3236}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 31.77, 'feels_like': 23.5, 'temp_min': 31.77, 'temp_max': 31.77, 'pressure': 1023, 'humidity': 68, 'sea_level': 1023, 'grnd_level': 1020}, 'visibility': 10000, 'wind': {'speed': 9.89, 'deg': 14, 'gust': 12.19}, 'clouds': {'all': 0}, 'dt': 1617637416, 'sys': {'country': 'JP', 'sunrise': 1617652270, 'sunset': 1617698929}, 'timezone': 32400, 'id': 2128975, 'name': 'Nemuro', 'cod': 200}
# {'coord': {'lon': 57.7, 'lat': -20.4081}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 84.56, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1015, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 60}, 'clouds': {'all': 40}, 'dt': 1617637417, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1617589035, 'sunset': 1617631571}, 'timezone': 14400, 'id': 934322, 'name': 'Mahébourg', 'cod': 200}
# {'coord': {'lon': 120.7333, 'lat': 49.2833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 32.11, 'feels_like': 23.23, 'temp_min': 32.11, 'temp_max': 32.11, 'pressure': 1018, 'humidity': 52, 'sea_level': 1018, 'grnd_level': 938}, 'visibility': 10000, 'wind': {'speed': 11.3, 'deg': 301, 'gust': 24.92}, 'clouds': {'all': 85}, 'dt': 1617637417, 'sys': {'country': 'CN', 'sunrise': 1617571578, 'sunset': 1617618778}, 'timezone': 28800, 'id': 2033536, 'name': 'Yakeshi', 'cod': 200}
# {'coord': {'lon': 147.2712, 'lat': -2.0226}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 81.14, 'feels_like': 86.56, 'temp_min': 81.14, 'temp_max': 81.14, 'pressure': 1007, 'humidity': 79, 'sea_level': 1007, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 2.93, 'deg': 6, 'gust': 3.96}, 'clouds': {'all': 99}, 'dt': 1617637418, 'sys': {'country': 'PG', 'sunrise': 1617653446, 'sunset': 1617696939}, 'timezone': 36000, 'id': 2092164, 'name': 'Lorengau', 'cod': 200}
# {'coord': {'lon': 125.4092, 'lat': -8.9266}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 59.72, 'feels_like': 59.34, 'temp_min': 59.72, 'temp_max': 59.72, 'pressure': 1010, 'humidity': 84, 'sea_level': 1010, 'grnd_level': 855}, 'visibility': 10000, 'wind': {'speed': 3.51, 'deg': 1, 'gust': 4.88}, 'clouds': {'all': 100}, 'dt': 1617637418, 'sys': {'country': 'TL', 'sunrise': 1617658878, 'sunset': 1617701999}, 'timezone': 32400, 'id': 1651810, 'name': 'Airai', 'cod': 200}
# {'coord': {'lon': 126.6992, 'lat': 62.0989}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -22.81, 'feels_like': -22.81, 'temp_min': -22.81, 'temp_max': -22.81, 'pressure': 1031, 'humidity': 100, 'sea_level': 1031, 'grnd_level': 1001}, 'visibility': 3770, 'wind': {'speed': 2.46, 'deg': 248, 'gust': 2.35}, 'clouds': {'all': 72}, 'dt': 1617637419, 'sys': {'country': 'RU', 'sunrise': 1617655155, 'sunset': 1617705103}, 'timezone': 32400, 'id': 2026861, 'name': 'Berdigestyakh', 'cod': 200}
# {'coord': {'lon': 86.3839, 'lat': 54.5368}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 32.68, 'feels_like': 27.09, 'temp_min': 32.68, 'temp_max': 32.68, 'pressure': 1020, 'humidity': 97, 'sea_level': 1020, 'grnd_level': 992}, 'visibility': 4131, 'wind': {'speed': 5.95, 'deg': 143, 'gust': 8.41}, 'clouds': {'all': 94}, 'dt': 1617637419, 'sys': {'country': 'RU', 'sunrise': 1617579413, 'sunset': 1617627427}, 'timezone': 25200, 'id': 1506192, 'name': 'Gramoteino', 'cod': 200}
# {'coord': {'lon': -27.0667, 'lat': 38.7333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 64.65, 'feels_like': 64.44, 'temp_min': 64.4, 'temp_max': 64.99, 'pressure': 1012, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 15.55, 'deg': 104, 'gust': 19.95}, 'clouds': {'all': 75}, 'dt': 1617637376, 'sys': {'type': 1, 'id': 6895, 'country': 'PT', 'sunrise': 1617607589, 'sunset': 1617653697}, 'timezone': 0, 'id': 3372760, 'name': 'Praia da Vitória', 'cod': 200}
# ...
# {'coord': {'lon': 23.1274, 'lat': -15.2484}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 78.13, 'feels_like': 77.58, 'temp_min': 78.13, 'temp_max': 78.13, 'pressure': 1011, 'humidity': 41, 'sea_level': 1011, 'grnd_level': 901}, 'visibility': 10000, 'wind': {'speed': 4.76, 'deg': 88, 'gust': 4.85}, 'clouds': {'all': 47}, 'dt': 1617637606, 'sys': {'country': 'ZM', 'sunrise': 1617597193, 'sunset': 1617640004}, 'timezone': 7200, 'id': 906054, 'name': 'Mongu', 'cod': 200}
# {'coord': {'lon': 133.0839, 'lat': 42.7297}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 38.46, 'feels_like': 38.46, 'temp_min': 38.46, 'temp_max': 38.46, 'pressure': 1021, 'humidity': 68, 'sea_level': 1021, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 1.03, 'deg': 82, 'gust': 3.85}, 'clouds': {'all': 22}, 'dt': 1617637607, 'sys': {'country': 'RU', 'sunrise': 1617655297, 'sunset': 1617701897}, 'timezone': 36000, 'id': 2013258, 'name': "Vrangel'", 'cod': 200}
# {'coord': {'lon': -77.0282, 'lat': -12.0432}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 75.22, 'feels_like': 75.87, 'temp_min': 73.4, 'temp_max': 77, 'pressure': 1012, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 180}, 'clouds': {'all': 0}, 'dt': 1617637415, 'sys': {'type': 1, 'id': 8682, 'country': 'PE', 'sunrise': 1617621147, 'sunset': 1617664116}, 'timezone': -18000, 'id': 3936456, 'name': 'Lima', 'cod': 200}
# {'coord': {'lon': -71.6856, 'lat': 42.207}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 53.73, 'feels_like': 50.16, 'temp_min': 52, 'temp_max': 55, 'pressure': 1008, 'humidity': 29}, 'visibility': 10000, 'wind': {'speed': 7, 'deg': 312, 'gust': 14}, 'clouds': {'all': 23}, 'dt': 1617637607, 'sys': {'type': 3, 'id': 2007757, 'country': 'US', 'sunrise': 1617618114, 'sunset': 1617664584}, 'timezone': -14400, 'id': 4938048, 'name': 'Grafton', 'cod': 200}
# {'coord': {'lon': -117.136, 'lat': 58.5169}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 28.4, 'feels_like': 28.4, 'temp_min': 28.4, 'temp_max': 28.4, 'pressure': 1005, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 210}, 'clouds': {'all': 90}, 'dt': 1617637494, 'sys': {'type': 1, 'id': 867, 'country': 'CA', 'sunrise': 1617627781, 'sunset': 1617676729}, 'timezone': -21600, 'id': 5975004, 'name': 'High Level', 'cod': 200}
# {'coord': {'lon': 48.1664, 'lat': 30.4397}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 82.4, 'feels_like': 80.06, 'temp_min': 82.4, 'temp_max': 82.4, 'pressure': 1015, 'humidity': 18}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 310}, 'clouds': {'all': 0}, 'dt': 1617637608, 'sys': {'type': 1, 'id': 7439, 'country': 'IR', 'sunrise': 1617589893, 'sunset': 1617635288}, 'timezone': 16200, 'id': 127319, 'name': 'Khorramshahr', 'cod': 200}
# {'coord': {'lon': -73.4, 'lat': 18.2833}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 81.01, 'feels_like': 84.31, 'temp_min': 81.01, 'temp_max': 81.01, 'pressure': 1015, 'humidity': 68, 'sea_level': 1015, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 1.07, 'deg': 102, 'gust': 3.62}, 'clouds': {'all': 52}, 'dt': 1617637609, 'sys': {'country': 'HT', 'sunrise': 1617619453, 'sunset': 1617664068}, 'timezone': -14400, 'id': 3731095, 'name': 'Aquin', 'cod': 200}
# {'coord': {'lon': -84.4562, 'lat': 11.6876}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.87, 'feels_like': 83.62, 'temp_min': 80.87, 'temp_max': 80.87, 'pressure': 1013, 'humidity': 65, 'sea_level': 1013, 'grnd_level': 992}, 'visibility': 10000, 'wind': {'speed': 12.06, 'deg': 53, 'gust': 16.64}, 'clouds': {'all': 98}, 'dt': 1617637609, 'sys': {'country': 'NI', 'sunrise': 1617622298, 'sunset': 1617666529}, 'timezone': -21600, 'id': 3617459, 'name': 'Nueva Guinea', 'cod': 200}
# {'coord': {'lon': 71.7632, 'lat': 54.3663}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 34.12, 'feels_like': 24.06, 'temp_min': 34.12, 'temp_max': 34.12, 'pressure': 1010, 'humidity': 93, 'sea_level': 1010, 'grnd_level': 994}, 'visibility': 10000, 'wind': {'speed': 15.75, 'deg': 248, 'gust': 28.99}, 'clouds': {'all': 100}, 'dt': 1617637609, 'sys': {'country': 'RU', 'sunrise': 1617582931, 'sunset': 1617630926}, 'timezone': 21600, 'id': 1494500, 'name': 'Poltavka', 'cod': 200}
# {'coord': {'lon': 147.1667, 'lat': -41.45}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 49.96, 'feels_like': 49.96, 'temp_min': 48.2, 'temp_max': 52, 'pressure': 1023, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 1.1, 'deg': 48, 'gust': 1.68}, 'clouds': {'all': 1}, 'dt': 1617637610, 'sys': {'type': 1, 'id': 9549, 'country': 'AU', 'sunrise': 1617654708, 'sunset': 1617695727}, 'timezone': 36000, 'id': 2160517, 'name': 'Launceston', 'cod': 200}
# City not found
# {'coord': {'lon': 88.3972, 'lat': 69.4865}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 22.28, 'feels_like': 11.07, 'temp_min': 22.28, 'temp_max': 22.28, 'pressure': 1009, 'humidity': 95, 'sea_level': 1009, 'grnd_level': 1000}, 'visibility': 137, 'wind': {'speed': 11.05, 'deg': 119, 'gust': 20.38}, 'snow': {'1h': 0.59}, 'clouds': {'all': 100}, 'dt': 1617637610, 'sys': {'country': 'RU', 'sunrise': 1617576782, 'sunset': 1617629092}, 'timezone': 25200, 'id': 1490256, 'name': 'Talnakh', 'cod': 200}
# {'coord': {'lon': -98.75, 'lat': 16.5167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 84.43, 'feels_like': 85.93, 'temp_min': 84.43, 'temp_max': 84.43, 'pressure': 1012, 'humidity': 51, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 4.41, 'deg': 219, 'gust': 2.93}, 'clouds': {'all': 4}, 'dt': 1617637611, 'sys': {'country': 'MX', 'sunrise': 1617625587, 'sunset': 1617670100}, 'timezone': -18000, 'id': 3516171, 'name': 'Barra de Tecoanapa', 'cod': 200}
# {'coord': {'lon': 165.677, 'lat': -21.6924}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 73.4, 'feels_like': 73.87, 'temp_min': 73.4, 'temp_max': 73.4, 'pressure': 1013, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 100}, 'clouds': {'all': 75}, 'dt': 1617637611, 'sys': {'type': 1, 'id': 7344, 'country': 'NC', 'sunrise': 1617649570, 'sunset': 1617691983}, 'timezone': 39600, 'id': 2140466, 'name': 'Moindou', 'cod': 200}
# {'coord': {'lon': -70.2075, 'lat': 8.6226}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 78.8, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1017, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 100}, 'dt': 1617637612, 'sys': {'type': 1, 'id': 8707, 'country': 'VE', 'sunrise': 1617618964, 'sunset': 1617663025}, 'timezone': -14400, 'id': 3648546, 'name': 'Barinas', 'cod': 200}
# {'coord': {'lon': 22.9573, 'lat': 37.9407}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 59, 'feels_like': 57.47, 'temp_min': 59, 'temp_max': 59, 'pressure': 1009, 'humidity': 61}, 'visibility': 7208, 'wind': {'speed': 4, 'deg': 138, 'gust': 10}, 'clouds': {'all': 100}, 'dt': 1617637612, 'sys': {'type': 3, 'id': 2002027, 'country': 'GR', 'sunrise': 1617595632, 'sunset': 1617641647}, 'timezone': 10800, 'id': 259289, 'name': 'Corinth', 'cod': 200}
# {'coord': {'lon': -133.7218, 'lat': 68.3499}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -4, 'feels_like': -24.5, 'temp_min': -4, 'temp_max': -4, 'pressure': 1016, 'humidity': 77}, 'visibility': 3165, 'wind': {'speed': 14.97, 'deg': 290, 'gust': 20.71}, 'clouds': {'all': 100}, 'dt': 1617637613, 'sys': {'type': 1, 'id': 1029, 'country': 'CA', 'sunrise': 1617630195, 'sunset': 1617682275}, 'timezone': -21600, 'id': 5983607, 'name': 'Inuvik', 'cod': 200}
# {'coord': {'lon': -96.667, 'lat': 40.8}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 67.78, 'feels_like': 67.46, 'temp_min': 66, 'temp_max': 70, 'pressure': 1008, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 170}, 'clouds': {'all': 1}, 'dt': 1617637441, 'sys': {'type': 1, 'id': 4736, 'country': 'US', 'sunrise': 1617624175, 'sunset': 1617670512}, 'timezone': -18000, 'id': 5072006, 'name': 'Lincoln', 'cod': 200}
# {'coord': {'lon': 152.8535, 'lat': -25.2986}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 73, 'feels_like': 74.61, 'temp_min': 73, 'temp_max': 73, 'pressure': 1007, 'humidity': 98}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 125, 'gust': 5.01}, 'clouds': {'all': 100}, 'dt': 1617637613, 'sys': {'type': 3, 'id': 2032484, 'country': 'AU', 'sunrise': 1617652757, 'sunset': 1617694949}, 'timezone': 36000, 'id': 2146219, 'name': 'Hervey Bay', 'cod': 200}
# {'coord': {'lon': -73.7849, 'lat': 2.1837}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 72.1, 'feels_like': 73.62, 'temp_min': 72.1, 'temp_max': 72.1, 'pressure': 1014, 'humidity': 98, 'sea_level': 1014, 'grnd_level': 987}, 'visibility': 5790, 'wind': {'speed': 1.57, 'deg': 164, 'gust': 5.28}, 'clouds': {'all': 100}, 'dt': 1617637614, 'sys': {'country': 'CO', 'sunrise': 1617619995, 'sunset': 1617663711}, 'timezone': -18000, 'id': 3827693, 'name': 'La Macarena', 'cod': 200}
# {'coord': {'lon': 38.2792, 'lat': 46.6989}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 40.24, 'feels_like': 33.89, 'temp_min': 40.24, 'temp_max': 40.24, 'pressure': 1008, 'humidity': 95, 'sea_level': 1008, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 10.11, 'deg': 337, 'gust': 13.13}, 'clouds': {'all': 100}, 'dt': 1617637614, 'sys': {'country': 'RU', 'sunrise': 1617591503, 'sunset': 1617638423}, 'timezone': 10800, 'id': 466885, 'name': 'Yeysk', 'cod': 200}
# {'coord': {'lon': -45.7167, 'lat': -1.4467}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 86.68, 'feels_like': 94.06, 'temp_min': 86.68, 'temp_max': 86.68, 'pressure': 1010, 'humidity': 64, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 8.81, 'deg': 72, 'gust': 16.06}, 'clouds': {'all': 85}, 'dt': 1617637615, 'sys': {'country': 'BR', 'sunrise': 1617613355, 'sunset': 1617656881}, 'timezone': -10800, 'id': 3403395, 'name': 'Cândido Mendes', 'cod': 200}
# {'coord': {'lon': -1.0519, 'lat': 44.5875}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 61.36, 'feels_like': 60.35, 'temp_min': 57.2, 'temp_max': 66, 'pressure': 1019, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 330}, 'clouds': {'all': 75}, 'dt': 1617637615, 'sys': {'type': 1, 'id': 6448, 'country': 'FR', 'sunrise': 1617601053, 'sunset': 1617647748}, 'timezone': 7200, 'id': 6621469, 'name': "Arrondissement d'Arcachon", 'cod': 200}
# {'coord': {'lon': 45.05, 'lat': -25.1667}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 71.2, 'feels_like': 71.4, 'temp_min': 71.2, 'temp_max': 71.2, 'pressure': 1012, 'humidity': 72, 'sea_level': 1012, 'grnd_level': 994}, 'visibility': 10000, 'wind': {'speed': 5.88, 'deg': 237, 'gust': 12.88}, 'clouds': {'all': 24}, 'dt': 1617637616, 'sys': {'country': 'MG', 'sunrise': 1617592208, 'sunset': 1617634469}, 'timezone': 10800, 'id': 1067565, 'name': 'Beloha', 'cod': 200}
# {'coord': {'lon': 132.56, 'lat': 33.2238}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 49.19, 'feels_like': 48.04, 'temp_min': 49.19, 'temp_max': 49.19, 'pressure': 1017, 'humidity': 69, 'sea_level': 1017, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 3.87, 'deg': 63, 'gust': 4.41}, 'clouds': {'all': 10}, 'dt': 1617637616, 'sys': {'country': 'JP', 'sunrise': 1617655872, 'sunset': 1617701573}, 'timezone': 32400, 'id': 1926020, 'name': 'Uwajima', 'cod': 200}
# {'coord': {'lon': 57.6608, 'lat': -20.0064}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 81, 'feels_like': 84.96, 'temp_min': 81, 'temp_max': 81, 'pressure': 1015, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 91, 'gust': 8.99}, 'clouds': {'all': 53}, 'dt': 1617637617, 'sys': {'type': 3, 'id': 2002134, 'country': 'MU', 'sunrise': 1617589033, 'sunset': 1617631591}, 'timezone': 14400, 'id': 934479, 'name': 'Grand Gaube', 'cod': 200}
# {'coord': {'lon': 60.6225, 'lat': 35.244}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 57.52, 'feels_like': 54.63, 'temp_min': 57.52, 'temp_max': 57.52, 'pressure': 1018, 'humidity': 35, 'sea_level': 1018, 'grnd_level': 915}, 'visibility': 10000, 'wind': {'speed': 8.84, 'deg': 95, 'gust': 12.48}, 'clouds': {'all': 49}, 'dt': 1617637617, 'sys': {'country': 'IR', 'sunrise': 1617586718, 'sunset': 1617632485}, 'timezone': 16200, 'id': 1159362, 'name': 'Torbat-e Jām', 'cod': 200}
# {'coord': {'lon': 29.0864, 'lat': 70.8578}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 34.66, 'feels_like': 23.29, 'temp_min': 33.8, 'temp_max': 35.6, 'pressure': 973, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 20.71, 'deg': 100}, 'clouds': {'all': 75}, 'dt': 1617637617, 'sys': {'type': 1, 'id': 1618, 'country': 'NO', 'sunrise': 1617590602, 'sunset': 1617643735}, 'timezone': 7200, 'id': 780687, 'name': 'Berlevåg', 'cod': 200}
# {'coord': {'lon': -4.7667, 'lat': 10.6333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 105.4, 'feels_like': 102.11, 'temp_min': 105.4, 'temp_max': 105.4, 'pressure': 1004, 'humidity': 15, 'sea_level': 1004, 'grnd_level': 973}, 'visibility': 10000, 'wind': {'speed': 2.66, 'deg': 190, 'gust': 7.16}, 'clouds': {'all': 1}, 'dt': 1617637618, 'sys': {'country': 'BF', 'sunrise': 1617603209, 'sunset': 1617647374}, 'timezone': 0, 'id': 2362909, 'name': 'Banfora', 'cod': 200}
# {'coord': {'lon': 140.3, 'lat': 35.1333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 49.14, 'feels_like': 49.14, 'temp_min': 45, 'temp_max': 51.01, 'pressure': 1019, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 62, 'gust': 11.01}, 'clouds': {'all': 65}, 'dt': 1617637512, 'sys': {'type': 3, 'id': 20334, 'country': 'JP', 'sunrise': 1617653936, 'sunset': 1617699795}, 'timezone': 32400, 'id': 2112309, 'name': 'Katsuura', 'cod': 200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * OPTIONAL: Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict={"City_Name":city_name, "Cloudiness":cloudiness, "Country":country, "Date":date, "Humidity":humidity, "Latitude":lat, "Longitude":lng, "Maximum_Temperature":max_temp, "Wind_Speed":wind_speed}
weather_df=pd.DataFrame(weather_dict)
weather_df.count()
# Out:
# City_Name              549
# Cloudiness             549
# Country                549
# Date                   549
# Humidity               549
# Latitude               549
# Longitude              549
# Maximum_Temperature    549
# Wind_Speed             549
# dtype: int64

# %%
display(weather_df.head())
# Out:
#      City_Name  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0      Qaanaaq         100      GL  1617637381        59   77.4840   -69.3632
# 1    Caravelas         100      BR  1617637382        57  -17.7125   -39.2481
# 2        Vogan          20      TG  1617637382        70    6.3333     1.5333
# 3      Ushuaia          75      AR  1617637158        70  -54.8000   -68.3000
# 4  New Norfolk           0      AU  1617637383        70  -42.7826   147.0587
#
#    Maximum_Temperature  Wind_Speed
# 0                 4.06       10.02
# 1                83.70        8.68
# 2                87.80       14.97
# 3                42.80       10.36
# 4                52.00        3.29

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Use matplotlib
# * OPTIONAL: Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()
ax.scatter(weather_df["Latitude"], weather_df["Maximum_Temperature"], color='cyan', edgecolor='black' )
ax.set_xlabel("Latitude")
ax.set_ylabel("Max Temperature (F)")
ax.set_title("City Latitude vs. Max Temperature (04/05/22)")
plt.grid(True)
plt.show()
plt.savefig('lat_vs_temp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
ax.scatter(weather_df["Latitude"], weather_df["Humidity"], color='cyan', edgecolor='black')
ax.set_xlabel("Latitude")
ax.set_ylabel("Humidity (%)")
ax.set_title("City Latitude vs. Humidity (04/05/22)")
plt.grid(True)
plt.show()
plt.savefig('lat_vs_humid.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
ax.scatter(weather_df["Latitude"], weather_df["Cloudiness"], color='cyan', edgecolor='black')
ax.set_xlabel("Latitude")
ax.set_ylabel("Cloudiness (%)")
ax.set_title("City Latitude vs. Cloudiness (04/05/22)")
plt.grid(True)
plt.show()
plt.savefig('lat_vs_cloud.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
ax.scatter(weather_df["Latitude"], weather_df["Wind_Speed"], color='cyan', edgecolor='black')
ax.set_xlabel("Latitude")
ax.set_ylabel("Wind Speed (mph)")
ax.set_title("City Latitude vs. Wind Speed (04/05/22)")
plt.grid(True)
plt.show()
plt.savefig('lat_vs_wind.png')

# %% [markdown]
# ### Use the Seaborn library to re-create 2-4 of the above plots.
# * Use the same data just make a different plot.
# * Note the differences in amount of code required to generate a similar plot.

# %%
import seaborn as sns
sns.set_style("whitegrid")
g=sns.scatterplot(x="Latitude", y="Maximum_Temperature", data=weather_df, color='cyan', edgecolor='black')
g.set_title("City Latitude vs. Max Temperature (04/05/22)")
g.set(ylabel="Max Temperature (F)")
plt.show()

# %%
sns.set_style("whitegrid")
g=sns.scatterplot(x="Latitude", y="Humidity", data=weather_df, color='cyan', edgecolor='black')
g.set_title("City Latitude vs. Humidity (04/05/22)")
g.set(ylabel="Humidity (%)")
plt.show()

# %% [markdown]
# ### As a Data-Scientist:
# In addition to generating data, munging data and plotting data you will also be responsible for *interpreting* data.
# * Provide a written description of three observable trends based on the data.

# %%
# The highest temperatures are concentrated closest to the equator, with temperatures dropping considerably the closer a city is to a latitude of 80 degrees.
# Humidity is lowest closest to the equator, with none of the cities that had humidity of less than 40 degrees farther than 60 degrees latitude from the equator.
# Most cities were experiencing a normal range wind speed of 20 mph or less, however the outliers were weighted heavily in the Northern Hemisphere and tended to be higher the closer the city was to the equator.

# %% [markdown]
# ### OPTIONAL Homework Problem:
# * Use a **different** api endpoint such as `Hourly Forecast 4 days` to get data.
# * Other weather api endpoints are documented [here](https://openweathermap.org/api).
# * You will have to change the URL parameters to get the data you want.
# * Get the data into a data structure of your choice. (Pandas, dicts, lists etc...)
# * Use the plotting library of your choice to make 1-4 plots of your choice.
